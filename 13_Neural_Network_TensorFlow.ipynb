# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
new_colors = {

    "black": [
        (0, 0, 0), (10, 10, 10), (20, 20, 20),
        (5, 5, 5), (15, 15, 15), (25, 25, 25),
        (8, 8, 8), (18, 18, 18), (28, 28, 28),
        (12, 12, 12), (22, 22, 22), (30, 30, 30),
        (3, 3, 3), (7, 7, 7), (14, 14, 14),
        (2, 2, 2), (4, 4, 4), (6, 6, 6)
    ],

    "white": [
        (255, 255, 255), (245, 245, 245), (235, 235, 235),
        (250, 250, 250), (240, 240, 240), (230, 230, 230),
        (248, 248, 248), (238, 238, 238), (228, 228, 228),
        (252, 252, 252), (242, 242, 242), (232, 232, 232),
        (255, 250, 250), (245, 240, 240), (235, 230, 230),
        (255, 245, 245), (250, 240, 240), (240, 235, 235)
    ],

    "gray": [
        (128, 128, 128), (100, 100, 100), (150, 150, 150),
        (120, 120, 120), (140, 140, 140), (160, 160, 160),
        (110, 110, 110), (130, 130, 130), (170, 170, 170),
        (90, 90, 90), (180, 180, 180), (200, 200, 200),
        (80, 80, 80), (190, 190, 190), (210, 210, 210),
        (95, 95, 95), (145, 145, 145), (155, 155, 155)
    ],

    "orange": [
        (255, 165, 0), (250, 150, 20), (240, 140, 10),
        (255, 180, 40), (255, 190, 60), (255, 200, 80),
        (230, 130, 0), (220, 120, 10), (210, 110, 20),
        (255, 170, 30), (255, 160, 50), (255, 150, 70),
        (200, 100, 0), (190, 90, 15), (180, 80, 10),
        (255, 200, 100), (255, 210, 120), (255, 180, 90)
    ],

    "brown": [
        (165, 42, 42), (150, 40, 30), (140, 35, 25),
        (180, 60, 50), (190, 70, 60), (200, 80, 70),
        (120, 30, 20), (110, 25, 15), (100, 20, 10),
        (175, 55, 45), (160, 45, 35), (185, 65, 55),
        (90, 15, 5), (130, 35, 25), (155, 50, 40),
        (170, 60, 50), (200, 90, 70), (140, 50, 30)
    ],

    "pink": [
        (255, 192, 203), (255, 182, 193), (255, 160, 180),
        (255, 170, 185), (255, 150, 170), (255, 130, 150),
        (240, 150, 170), (230, 140, 160), (220, 130, 150),
        (255, 210, 220), (255, 200, 210), (245, 190, 200),
        (235, 180, 190), (225, 170, 180), (215, 160, 170),
        (255, 220, 230), (255, 200, 225), (255, 180, 200)
    ],

    "purple": [
        (128, 0, 128), (148, 0, 148), (160, 20, 160),
        (140, 10, 140), (155, 25, 155), (170, 40, 170),
        (110, 0, 110), (120, 10, 120), (130, 20, 130),
        (180, 60, 180), (190, 70, 190), (200, 80, 200),
        (100, 0, 100), (140, 30, 140), (150, 40, 150),
        (160, 60, 160), (170, 50, 170), (180, 40, 180)
    ],

    "lime": [
        (191, 255, 0), (180, 240, 20), (170, 235, 10),
        (200, 255, 60), (210, 255, 80), (220, 255, 100),
        (160, 220, 0), (150, 210, 10), (140, 200, 20),
        (210, 240, 30), (220, 250, 50), (200, 230, 40),
        (150, 190, 0), (170, 210, 20), (180, 220, 30),
        (230, 255, 120), (240, 255, 140), (200, 230, 100)
    ],

    "navy": [
        (0, 0, 128), (10, 10, 150), (15, 15, 140),
        (20, 20, 160), (30, 30, 170), (40, 40, 180),
        (0, 0, 100), (5, 5, 110), (8, 8, 120),
        (50, 50, 200), (60, 60, 210), (70, 70, 220),
        (0, 0, 90), (0, 0, 80), (10, 10, 90),
        (30, 30, 150), (40, 40, 160), (20, 20, 140)
    ],

    "maroon": [
        (128, 0, 0), (150, 20, 10), (140, 15, 15),
        (160, 30, 20), (170, 40, 25), (180, 50, 30),
        (110, 0, 0), (120, 10, 10), (130, 15, 15),
        (190, 60, 40), (200, 70, 50), (210, 80, 60),
        (100, 0, 0), (140, 20, 20), (150, 25, 25),
        (160, 35, 35), (170, 45, 45), (180, 55, 55)
    ],

    "olive": [
        (128, 128, 0), (140, 140, 10), (150, 150, 20),
        (160, 160, 30), (170, 170, 40), (180, 180, 50),
        (110, 110, 0), (120, 120, 10), (130, 130, 20),
        (190, 190, 60), (200, 200, 70), (210, 210, 80),
        (90, 90, 0), (100, 100, 10), (115, 115, 20),
        (155, 155, 25), (165, 165, 35), (175, 175, 45)
    ],
}

# %%
X = []
Y = []

for label, rgb_list in colors.items():
    for rgb in rgb_list:
        X.append(rgb)
        Y.append(label)

X = np.array(X, dtype=np.float32)
Y = np.array(Y)
print(X.shape, Y.shape)
# Out:
# (108, 3) (108,)

# %%
# Normalize RGB to 0-1
X = X / 255.0  

# Encode labels
unique_labels = list(colors.keys())
label_to_index = {label: idx for idx, label in enumerate(unique_labels)}
y_encoded = np.array([label_to_index[label] for label in Y])
y_one_hot = to_categorical(y_encoded, num_classes=len(unique_labels))

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y_one_hot, test_size=0.2, random_state=42)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(3,)),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(len(unique_labels), activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_21 (Dense)                │ (None, 8)              │            32 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 6)              │            54 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 158 (632.00 B)
#  Trainable params: 158 (632.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=4, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.1858 - loss: 1.8491 - val_accuracy: 0.0909 - val_loss: 1.9213
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2293 - loss: 1.7633 - val_accuracy: 0.0909 - val_loss: 1.8763
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1937 - loss: 1.7324 - val_accuracy: 0.0909 - val_loss: 1.8340
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1875 - loss: 1.6992 - val_accuracy: 0.0000e+00 - val_loss: 1.8094
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2123 - loss: 1.7167 - val_accuracy: 0.0455 - val_loss: 1.7721
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2049 - loss: 1.6807 - val_accuracy: 0.0909 - val_loss: 1.7441
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2695 - loss: 1.6767 - val_accuracy: 0.1364 - val_loss: 1.7102
# Epoch 8/100
# ...

# %%
# Convert the model
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save to file
with open("color_detector.tflite", "wb") as f:
    f.write(tflite_model)

print("TFLite model saved as color_detector.tflite")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\HP\AppData\Local\Temp\tmpcdwgocg1\assets
# INFO:tensorflow:Assets written to: C:\Users\HP\AppData\Local\Temp\tmpcdwgocg1\assets
# Saved artifact at 'C:\Users\HP\AppData\Local\Temp\tmpcdwgocg1'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 3), dtype=tf.float32, name='keras_tensor_28')
# Output Type:
#   TensorSpec(shape=(None, 6), dtype=tf.float32, name=None)
# Captures:
#   1636808831440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1636808822416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1636808818960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1636808819344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1636808830864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1636808831056: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite model saved as color_detector.tflite

# %%
def predict_color_tflite(rgb):
    rgb = np.array(rgb, dtype=np.float32).reshape(1, 3) / 255.0

    interpreter = tf.lite.Interpreter(model_path="color_detector.tflite")
    interpreter.allocate_tensors()

    input_idx = interpreter.get_input_details()[0]['index']
    output_idx = interpreter.get_output_details()[0]['index']

    interpreter.set_tensor(input_idx, rgb)
    interpreter.invoke()

    output_data = interpreter.get_tensor(output_idx)
    pred_index = np.argmax(output_data)

    # Find label
    for label, idx in label_to_index.items():
        if idx == pred_index:
            return label

# %%
# ------- Existing Colors -------
print(predict_color_tflite([255, 40, 40]))    # Expected: red
print(predict_color_tflite([30, 255, 30]))    # Expected: green
print(predict_color_tflite([40, 40, 255]))    # Expected: blue
print(predict_color_tflite([250, 250, 40]))   # Expected: yellow
print(predict_color_tflite([20, 230, 230]))   # Expected: cyan
# Out:
# red
# green
# blue
# yellow
# cyan
